# 13    $600  No. 1: Lettered in hoops, football & lacrosse ...
# 14    $600  On June 28, 1994 the nat'l weather service beg...
# 15    $600  This company's Accutron watch, introduced in 1...
# 16    $600  Outlaw: "Murdered by a traitor and a coward wh...
# 17    $600  A small demon, or a mischievous child (who mig...
# 18    $800  Karl led the first of these Marxist organizati...
# 19    $800  No. 10: FB/LB for Columbia U. in the 1920s; MV...
# 20    $800  Africa's lowest temperature was 11 degrees bel...
# 21    $800  Edward Teller & this man partnered in 1898 to ...
# 22  $2,000  1939 Oscar winner: "...you are a credit to you...
# 23    $800  In geologic time one of these, shorter than an...
# 24   $1000  This Asian political party was founded in 1885...
#
#                                                Answer
# 0                                          Copernicus
# 1                                          Jim Thorpe
# 2                                             Arizona
# 3                                          McDonald's
# 4                                          John Adams
# 5                                             the ant
# 6                                      the Appian Way
# 7                                      Michael Jordan
# 8                                          Washington
# 9                                      Crate & Barrel
# 10                                     Jackie Gleason
# 11                                            the cud
# 12                              Ceylon (or Sri Lanka)
# 13                                          Jim Brown
# 14                                       the UV index
# 15                                             Bulova
# 16                                        Jesse James
# 17                                                imp
# 18                                  the International
# 19                                       (Lou) Gehrig
# 20                                            Morocco
# 21                                      (Paul) Bonwit
# 22  Hattie McDaniel (for her role in Gone with the...
# 23                                                era
# 24                                 the Congress Party

# %% [markdown]
# Specify subsets, here we're only going to look at these specific values.

# %%
df = df[['Round', 'Value', 'Question', 'Answer']]
df.head(5)
# Out:
#        Round Value                                           Question  \
# 0  Jeopardy!  $200  For the last 8 years of his life, Galileo was ...
# 1  Jeopardy!  $200  No. 2: 1912 Olympian; football star at Carlisl...
# 2  Jeopardy!  $200  The city of Yuma in this state has a record av...
# 3  Jeopardy!  $200  In 1963, live on "The Art Linkletter Show", th...
# 4  Jeopardy!  $200  Signer of the Dec. of Indep., framer of the Co...
#
#        Answer
# 0  Copernicus
# 1  Jim Thorpe
# 2     Arizona
# 3  McDonald's
# 4  John Adams

# %% [markdown]
# Clean Data to remove Instances of Final Jeopary and 'None' Values, as they do not factor into our calculations.

# %%
df = df[~df.Round.str.contains('Final')]
df = df[~df.Value.str.contains('None')]

# %% [markdown]
# Create new columns for both `Words in Question` and `Words in Answer` by spliting strings in cells by the amount of spaces.  This creates a list with all words in a cell, then counting the size of that list with the `len()` function gives us the amount of words in each cell.

# %%
df['Words in Question'] = df['Question'].str.split().str.len()
df['Words in Answer'] = df['Answer'].str.split().str.len()

# %% [markdown]
# Remove all rows that have Nan in "Words in Answer"

# %%
df = df[df['Words in Answer'].notna()]

# %% [markdown]
# Notice that Value is currently being treated as categorical variable. Clean up this column and cast them to a float because we'll need to perform mathematical operations on these columns.

# %%
df['Value'] = df['Value'].str.replace('$','').str.replace(',', '').astype(float)
df
# Out:
# /var/folders/88/4dvfqb3n3kj5bjw1_47fpmk40000gn/T/ipykernel_35673/2060277076.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Value'] = df['Value'].str.replace('$','').str.replace(',', '').astype(float)
#                    Round   Value  \
# 0              Jeopardy!   200.0
# 1              Jeopardy!   200.0
# 2              Jeopardy!   200.0
# 3              Jeopardy!   200.0
# 4              Jeopardy!   200.0
# ...                  ...     ...
# 216924  Double Jeopardy!  2000.0
# 216925  Double Jeopardy!  2000.0
# 216926  Double Jeopardy!  2000.0
# 216927  Double Jeopardy!  2000.0
# 216928  Double Jeopardy!  2000.0
#
#                                                  Question        Answer  \
# 0       For the last 8 years of his life, Galileo was ...    Copernicus
# 1       No. 2: 1912 Olympian; football star at Carlisl...    Jim Thorpe
# 2       The city of Yuma in this state has a record av...       Arizona
# 3       In 1963, live on "The Art Linkletter Show", th...    McDonald's
# 4       Signer of the Dec. of Indep., framer of the Co...    John Adams
# ...                                                   ...           ...
# 216924  In 2006 the cast of this long-running hit emba...         Stomp
# 216925  This Puccini opera turns on the solution to 3 ...      Turandot
# 216926  In North America this term is properly applied...    a titmouse
# 216927  In Penny Lane, where this "Hellraiser" grew up...  Clive Barker
# 216928  From Ft. Sill, Okla. he made the plea, Arizona...      Geronimo
#
#         Words in Question  Words in Answer
# 0                      18              1.0
# 1                      19              2.0
# 2                      18              1.0
# 3                      14              1.0
# 4                      18              2.0
# ...                   ...              ...
# 216924                 22              1.0
# 216925                 14              1.0
# 216926                 18              2.0
# 216927                 16              2.0
# 216928                 24              1.0
#
# [213296 rows x 6 columns]

# %%
X = df.loc[:, ['Value', 'Words in Question']].values
distorsions = []
K = range(1, 20)

for k in K:
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42)
    kmeans.fit(X)
    distorsions.append(kmeans.inertia_)
    
plt.plot(K, distorsions, 'bx-')
plt.grid(True)
plt.show()

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X)
kmeans.cluster_centers_
# Out:
# array([[1870.80390744,   15.5223824 ],
#        [ 360.81865683,   14.04582408],
#        [5153.68303187,   16.03186908],
#        [ 939.82996559,   14.93421152]])

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=42)
y_kmeans = kmeans.fit_predict(X)
y_kmeans
# Out:
# array([0, 0, 0, ..., 3, 3, 3], dtype=int32)

# %%
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], c = 'red')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], c = 'blue')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], c = 'green')
plt.scatter(X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], c = 'purple')
plt.xlabel('Value')
plt.ylabel('Words in Question')
# Out:
# Text(0, 0.5, 'Words in Question')
